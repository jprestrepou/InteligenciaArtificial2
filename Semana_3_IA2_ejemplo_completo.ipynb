# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-842dfee5-3a9d-4196-9c04-27ea3b83e375" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-842dfee5-3a9d-4196-9c04-27ea3b83e375">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras import optimizers

dataset = loadtxt('Clase 3 - pima-indians-diabetes.data.txt', delimiter=',')

X = dataset[:, 0:8]
Y = dataset[:,8]

model=Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(2, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(1, activation='sigmoid'))


model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(learning_rate=0.00000000001),
              metrics=['accuracy'])

model.fit(X, Y, epochs=15, batch_size=5)

#Por ahora evaluamos con los mismos datos, no tiene mucho sentido so far.
print(model.evaluate(X, Y))
print(model.metrics_names)

#En lugar de predecir, y luego round.
predictions = model.predict(X)

for i, x in enumerate(X):
    print(x, Y[i], predictions[i])
# Out:
# Epoch 1/15
# 154/154 [==============================] - 2s 3ms/step - loss: 0.6938 - accuracy: 0.3620
# Epoch 2/15
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6938 - accuracy: 0.3620
# Epoch 3/15
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6938 - accuracy: 0.3620
# Epoch 4/15
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6938 - accuracy: 0.3620
# Epoch 5/15
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6938 - accuracy: 0.3620
# Epoch 6/15
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6938 - accuracy: 0.3620
# Epoch 7/15
# 154/154 [==============================] - 0s 2ms/step - loss: 0.6938 - accuracy: 0.3620
# Epoch 8/15
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6938 - accuracy: 0.3620
# Epoch 9/15
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6938 - accuracy: 0.3620
# Epoch 10/15
# ...
